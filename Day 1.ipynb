# %%
name = "John"
age = 25
salary = 50000
print(name)
print(age)
print(salary)
# Out:
# John
# 25
# 50000

# %%
marks = [80, 75, 90, 88]
print(marks)
print(marks[0])
# Out:
# [80, 75, 90, 88]
# 80

# %%
student = {    
"name": "John",    
"age": 20,    
"course": "Data Science"}

print(student["name"])
# Out:
# John

# %%
customer = "Alice"
balance = 15000

print("Customer:", customer)
print("Balance:", balance)
# Out:
# Customer: Alice
# Balance: 15000

# %%
sales = [100, 200, 150, 300]

for sale in sales:    
	print(sale)
# Out:
# 100
# 200
# 150
# 300

# %%
sales = [100, 200, 150, 300]
total = 0

for sale in sales:    
	total += sale

print("Total Sales:", total)
# Out:
# Total Sales: 750

# %%
count = 1

while count <= 5:    
	print(count)    
	count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
age = 20

if age >= 18:    
	print("Adult")
else:    
	print("Minor")
# Out:
# Adult

# %%
marks = [45, 78, 30, 90, 60]

for mark in marks:    
	if mark >= 50:        
		print(mark, "Pass")    
	else:        
		print(mark, "Fail")
# Out:
# 45 Fail
# 78 Pass
# 30 Fail
# 90 Pass
# 60 Pass

# %%
numbers = [10, -5, 20, -3, 15]

for num in numbers:    
	if num < 0:        
		continue    

	print(num)
# Out:
# 10
# 20
# 15

# %%
transactions = [500, 2000, 15000, 800, 25000]

for amount in transactions:    
	if amount > 10000:        
		print(amount, "Suspicious")    
	else:        
		print(amount, "Normal")
# Out:
# 500 Normal
# 2000 Normal
# 15000 Suspicious
# 800 Normal
# 25000 Suspicious

# %%
marks = [78, 45, 90, 67, 34, 88]

total = 0

for mark in marks:    
	total += mark

average = total / len(marks)

print("Average:", average)

for mark in marks:    
	if mark >= 50:        
		print(mark, "Pass")    
	else:        
		print(mark, "Fail")
# Out:
# Average: 67.0
# 78 Pass
# 45 Fail
# 90 Pass
# 67 Pass
# 34 Fail
# 88 Pass

# %%
# Store Name, Age, and City

name = "Rahul"
age = 22
city = "Hyderabad"

# Print the values

print("Name:", name)
print("Age:", age)
print("City:", city)
# Out:
# Name: Rahul
# Age: 22
# City: Hyderabad
